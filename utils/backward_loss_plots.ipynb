# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import os

# %%
file_name = r"/Users/paopao_ch/Documents/projects/v1_modelling/Mouse-V1-Pytorch/log_forwards.log"

losses = {
    "loss" : [],
}

with open(file_name, "r") as f:
    for line in f:
        words = line.split(" ")
        if words[0] == "loss:":
            losses["loss"].append(float(words[1]))
# df = pd.DataFrame(data=losses)

# %%
plt.plot(losses["loss"])
plt.title("Loss overtime for forward mode gradient descent")
plt.xlabel("Iteration")
plt.ylabel("MMD Loss")
# Out:
# Text(0, 0.5, 'MMD Loss')

# %%
from torch import tensor
import torch



for item in [tensor(-5.1454, device='cpu', dtype=torch.float64), tensor(-19.9875, device='cpu', dtype=torch.float64), tensor(2.0304, device='cpu', dtype=torch.float64), tensor(-14.7350, device='cpu', dtype=torch.float64), tensor(-1.9717, device='cpu', dtype=torch.float64), tensor(5.9933, device='cpu', dtype=torch.float64), tensor(-2.4430, device='cpu', dtype=torch.float64), tensor(6.0014, device='cpu', dtype=torch.float64), tensor(-116.7424, device='cpu', dtype=torch.float64), tensor(-131.9390, device='cpu', dtype=torch.float64), tensor(-131.5753, device='cpu', dtype=torch.float64), tensor(-131.8793, device='cpu', dtype=torch.float64)]:
    print(float(item))
# Out:
# -5.1454
# -19.9875
# 2.0304
# -14.735
# -1.9717
# 5.9933
# -2.443
# 6.0014
# -116.7424
# -131.939
# -131.5753
# -131.8793

# %%
[-5.1454, -19.9875, 2.0304, -14.735, -1.9717, 5.9933, -2.443, 6.0014, -116.7424, -131.939, -131.5753, -131.8793]
