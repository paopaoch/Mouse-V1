# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import os

# %%
file_name = r"/Users/paopao_ch/Documents/projects/v1_modelling/Mouse-V1-Pytorch/log_backwards_bessel.log"

losses = {
    "loss" : [],
}

with open(file_name, "r") as f:
    for line in f:
        words = line.split(" ")
        if words[0] == "loss:":
            losses["loss"].append(float(words[1]))
# df = pd.DataFrame(data=losses)

# %%
plt.plot(losses["loss"][4:])
plt.title("Loss overtime for forward mode gradient descent")
plt.xlabel("Iteration")
plt.ylabel("MMD Loss")
# Out:
# Text(0, 0.5, 'MMD Loss')

# %%
from torch import tensor
import torch


some_list = []
for item in [tensor(-6.5146, device='cpu', dtype=torch.float64), tensor(-18.3078, device='cpu', dtype=torch.float64), tensor(1.9324, device='cpu', dtype=torch.float64), tensor(-15.0128, device='cpu', dtype=torch.float64), tensor(-2.5468, device='cpu', dtype=torch.float64), tensor(5.1358, device='cpu', dtype=torch.float64), tensor(-2.6673, device='cpu', dtype=torch.float64), tensor(4.7931, device='cpu', dtype=torch.float64), tensor(-146.3454, device='cpu', dtype=torch.float64), tensor(-141.0747, device='cpu', dtype=torch.float64), tensor(-150.1062, device='cpu', dtype=torch.float64), tensor(-124.7299, device='cpu', dtype=torch.float64)]:
    some_list.append(float(item))
some_list
# Out:
# [-6.5146,
#  -18.3078,
#  1.9324,
#  -15.0128,
#  -2.5468,
#  5.1358,
#  -2.6673,
#  4.7931,
#  -146.3454,
#  -141.0747,
#  -150.1062,
#  -124.7299]
