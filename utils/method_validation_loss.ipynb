# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from os import listdir
from os.path import isfile, join


path = r"/Users/paopao_ch/Documents/projects/v1_modelling/Mouse-V1-Pytorch/results/backprop1000/method_validation"
files = [f for f in listdir(path) if isfile(join(path, f))]

# %%
losses = []

for filename in files:
    loss = []
    with open(f"{path}/{filename}", "r") as f:
        for line in f:
            words = line.split(" ")
            if words[0] == "loss:":
                loss.append(float(words[1]))
    losses.append(loss)

# %%
for loss in losses:
    plt.plot(loss)
plt.ylim(0, 1)
plt.show()

# %%
for i, loss in enumerate(losses):
    plt.plot(loss, label=f"{i}")
plt.ylim(0.005, 0.02)
plt.xlim(0, 100)
plt.legend()
plt.show()

# %%
files[24]
# Out:
# 'log_method_val_1714940765.1700659.log'

# %%
file_name = r"/Users/paopao_ch/Documents/projects/v1_modelling/Mouse-V1-Pytorch/results/backprop1000/at_minima.log"

at_minima_loss =[]

with open(file_name, "r") as f:
    for line in f:
        words = line.split(" ")
        if words[0] == "loss:":
            at_minima_loss.append(float(words[1]))
# df = pd.DataFrame(data=losses)

# %%
plt.plot(losses[24], label="lowest loss curve from training")
plt.plot(at_minima_loss, label="loss curve at minima")
plt.ylim(0.005, 0.02)
plt.xlim(0, 70)
plt.legend()
plt.show()

# %%
43
bessel_val: 0.0
loss: 0.007062256336212158
mean_list = [0.587113, -1.006514, -1.494353, -0.07066, -3.455629, -0.830209, 0.482497, 1.634026, 0.652712, 1.989928, -0.780589, 0.111335]
loss_diff: 8.157491538440809e-05
