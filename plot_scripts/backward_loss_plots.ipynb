# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import os

# %%
file_name = r"/Users/paopao_ch/Documents/projects/v1_modelling/Mouse-V1-Pytorch/results/xNES_JSD/GD_using_xNES_minima/log_method_val_1715113858.0718982.log"

losses = {
    "loss" : [],
}

with open(file_name, "r") as f:
    for line in f:
        words = line.split(" ")
        if words[0] == "loss:":
            losses["loss"].append(float(words[1]))
# df = pd.DataFrame(data=losses)

# %%
plt.plot(losses["loss"])
plt.title("Loss overtime for backward mode gradient descent")
plt.xlabel("Iteration")
plt.ylabel("MMD Loss")
# Out:
# Text(0, 0.5, 'MMD Loss')

# %%
from torch import tensor
import torch


some_list = []
for item in [tensor(-5.4272, device='cpu', dtype=torch.float64), tensor(-20.2403, device='cpu', dtype=torch.float64), tensor(2.3288, device='cpu', dtype=torch.float64), tensor(-15.6170, device='cpu', dtype=torch.float64), tensor(-2.1668, device='cpu', dtype=torch.float64), tensor(6.0285, device='cpu', dtype=torch.float64), tensor(-2.0068, device='cpu', dtype=torch.float64), tensor(5.9676, device='cpu', dtype=torch.float64), tensor(-136.0089, device='cpu', dtype=torch.float64), tensor(-130.9260, device='cpu', dtype=torch.float64), tensor(-129.7371, device='cpu', dtype=torch.float64), tensor(-133.2599, device='cpu', dtype=torch.float64)]:
    some_list.append(float(item))
some_list
# Out:
# [-5.4272,
#  -20.2403,
#  2.3288,
#  -15.617,
#  -2.1668,
#  6.0285,
#  -2.0068,
#  5.9676,
#  -136.0089,
#  -130.926,
#  -129.7371,
#  -133.2599]

# %%
[-2.053149, -3.054712, -1.59683, -2.808178 -2.085715, -0.203235, -2.098644, -0.197447 -1.527493, -1.53514, -1.536685, -1.527663]
