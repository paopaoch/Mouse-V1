# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 18})
sns.set(font_scale=3)

# %%
def plot_data_bar(df):
    df_melted = df.melt(id_vars='type', var_name='Parameter', value_name='Value')
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Parameter', y='Value', hue='type', data=df_melted)
    plt.xlabel('')
    plt.ylabel('Values')
    plt.legend(title='')
    plt.show()

# %%
data = [
    {"J EE": 11.31, "J EI": 4.52, "J IE": 16.97, "J II": 5.66, "type": "ground truth"},
    {"J EE": 15, "J EI": 7, "J IE": 20, "J II": 4, "type": "starting"},
    {"J EE": 3.84, "J EI": 1.92, "J IE": 23.6, "J II": 22.53, "type": "optimised"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
data = [
    {"P EE": 0.11, "P EI": 0.45, "P IE": 0.11, "P II": 0.45, "type": "ground truth"},
    {"P EE": 0.22, "P EI": 0.35, "P IE": 0.22, "P II": 0.35, "type": "starting"},
    {"P EE": 0.06, "P EI": 0.18, "P IE": 0.27, "P II": 0.67, "type": "optimised"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
data = [
    {"W EE": 32, "W EI": 32, "W IE": 32, "W II": 32, "type": "ground truth"},
    {"W EE": 45, "W EI": 45, "W IE": 45, "W II": 45, "type": "starting"},
    {"W EE": 16, "W EI": 29, "W IE": 54, "W II": 82, "type": "optimised"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
data = [
    {"J_EE": 11.31, "J_EI": 4.52, "J_IE": 16.97, "J_II": 5.66, "type": "ground truth"},
    {"J_EE": 64.27, "J_EI": 26.77, "J_IE": 18.33, "J_II": 48.23, "type": "Pred Low Contrast Skew"},
    {"J_EE": 22.56,"J_EI": 58.96,"J_IE": 13.62,"J_II": 56.84, "type": "Pred Med Contrast Skew"},
    {"J_EE": 55.9, "J_EI": 53.85, "J_IE": 52.57, "J_II": 43.65, "type": "Pred High Contrast Skew"}
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
data = [
    {"P_EE": 0.11, "P_EI": 0.45, "P_IE": 0.11, "P_II": 0.45, "type": "ground truth"},
    {"P_EE": 0.03, "P_EI": 0.3, "P_IE": 0.62, "P_II": 0.84, "type": "Pred Low Contrast Skew"},
    {"P_EE": 0.35, "P_EI": 0.18, "P_IE": 0.59, "P_II": 0.69, "type": "Pred Med Contrast Skew"},
    {"P_EE": 0.07, "P_EI": 0.39, "P_IE": 0.15, "P_II": 0.81, "type": "Pred High Contrast Skew"}
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
data = [
    {"w_EE": 32, "w_EI": 32, "w_IE": 32, "w_II": 32, "type": "ground truth"},
    {"w_EE": 118, "w_EI": 158, "w_IE": 67, "w_II": 95, "type": "Pred Low Contrast Skew"},
    {"w_EE": 17, "w_EI": 99, "w_IE": 141, "w_II": 142, "type": "Pred Med Contrast Skew"},
    {"w_EE": 157, "w_EI": 139, "w_IE": 119, "w_II": 95, "type": "Pred High Contrast Skew"}
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
# config 13 vs CNN

data = [
    {"J_EE": 11.31, "J_EI": 4.52, "J_IE": 16.97, "J_II": 5.66, "type": "ground truth"},
    {"J_EE": 14.4286, "J_EI": 36.9132, "J_IE": 32.0481, "J_II": 27.1053, "type": "predicted"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
# config 13 vs CNN

data = [
    {"P_EE": 0.11, "P_EI": 0.45, "P_IE": 0.11, "P_II": 0.45, "type": "ground truth"},
    {"P_EE": 0.2227, "P_EI": 0.2886, "P_IE": 0.4443, "P_II": 0.5751, "type": "predicted"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
# config 13 vs CNN

data = [
    {"w_EE": 32, "w_EI": 32, "w_IE": 32, "w_II": 32, "type": "ground truth"},
    {"w_EE": 82.5073, "w_EI": 81.2445, "w_IE": 87.0794, "w_II": 106.8106, "type": "predicted"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
# GT and Params from GD

data = [
    {"$J_{EE}$": 11.31, "$J_{EI}$": 4.52, "$J_{IE}$": 16.97, "$J_{II}$": 5.66, "type": "ground truth"},
    {"$J_{EE}$": 11.29802503281081, "$J_{EI}$": 4.522827941723933, "$J_{IE}$": 16.91984464862612, "$J_{II}$": 5.685246045963682, "type": "predicted"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
data = [
    {"$P_{EE}$": 0.11, "$P_{EI}$": 0.45, "$P_{IE}$": 0.11, "$P_{II}$": 0.45, "$q_{ff}$": 0.2, "type": "ground truth"},
    {"$P_{EE}$": 0.10987052175269874, "$P_{EI}$": 0.450022578891802, "$P_{IE}$": 0.10942363913868788, "$P_{II}$": 0.4501796707211307, "$q_{ff}$": 0.19, "type": "predicted"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
data = [
    {"$w_{EE}$": 32, "$w_{EI}$": 32, "$w_{IE}$": 32, "$w_{II}$": 32, "type": "ground truth"},
    {"$w_{EE}$": 31.988171474406837, "$w_{EI}$": 32.00627228666443, "$w_{IE}$": 31.927193004833576, "$w_{II}$": 32.06133434656243, "type": "predicted"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# 31.988171474406837, 32.00627228666443, 31.927193004833576, 32.06133434656243]

# %%
# [4.7344082724796825, 2.0559045162675154, 1.0884653064264114, 1.1739788091249261, 
# 0.01777311993751983, 0.020112395167326626, 0.5271682006597433, 0.031278319105348215, 
# 173.6898817269691, 38.36749781522269, 152.53782512199058, 163.0815401895009]

data = [
    {"$J_{EE}$": 11.31 / (800 ** 0.5), "$J_{EI}$": 4.52 / (200 ** 0.5), "$J_{IE}$": 16.97 / (800 ** 0.5), "$J_{II}$": 5.66 / (200 ** 0.5), "type": "ground truth"},
    {"$J_{EE}$": 4.7344082724796825 / (800 ** 0.5), "$J_{EI}$": 2.0559045162675154 / (200 ** 0.5), "$J_{IE}$": 1.0884653064264114 / (800 ** 0.5), "$J_{II}$": 1.1739788091249261 / (200 ** 0.5), "type": "predicted"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# %%
data = [
    {"$P_{EE}$": 0.11, "$P_{EI}$": 0.45, "$P_{IE}$": 0.11, "$P_{II}$": 0.45, "$q_{ff}$": 0.2, "type": "ground truth"},
    {"$P_{EE}$": 0.01777311993751983, "$P_{EI}$": 0.020112395167326626, "$P_{IE}$": 0.5271682006597433, "$P_{II}$": 0.031278319105348215, "$q_{ff}$": 0.07, "type": "predicted"},
]

df = pd.DataFrame(data)
plot_data_bar(df)
# 0.01777311993751983, 0.020112395167326626, 0.5271682006597433, 0.031278319105348215,

# %%
data = [
    {"$w_{EE}$": 32, "$w_{EI}$": 32, "$w_{IE}$": 32, "$w_{II}$": 32, "type": "ground truth"},
    {"$w_{EE}$": 173.6898817269691, "$w_{EI}$": 38.36749781522269, "$w_{IE}$": 152.53782512199058, "$w_{II}$": 163.0815401895009, "type": "predicted"},
]

df = pd.DataFrame(data)
plot_data_bar(df)

# 173.6898817269691, 38.36749781522269, 152.53782512199058, 163.0815401895009]
